# %%
import pandas as pd
import tensorflow as tf
from tensorflow import keras
import numpy as np
from matplotlib import pyplot as plt

# %%
(X_train,Y_train),(x_test,y_test)=keras.datasets.cifar10.load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
def plot(index):
  plt.figure(figsize=(10,1))
  plt.imshow(X_train[index])
  plt.axis('off')

# %%
plot(0)

# %%
plot(1)

# %%
plot(2)

# %%
plot(3)

# %%
plot(4)

# %%
plot(5)

# %%
plot(6)

# %%
plot(7)

# %%
plot(8)

# %%
plot(9)

# %% [markdown]
# classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
classes = ["airplane","automobile","bird","cat","deer","dog","frog","horse","ship","truck"]

# %%
Y_train_categorical=keras.utils.to_categorical(
  Y_train,num_classes=10,dtype='float32'
)

# %%
Y_train_categorical.shape
# Out:
# (50000, 10)

# %%
y_test_categorical=keras.utils.to_categorical(
  y_test,num_classes=10,dtype='float32'
)

# %%
model=keras.Sequential([
  keras.layers.Flatten(input_shape=(32,32,3)),
  keras.layers.Dense(3000,activation='relu'),
  keras.layers.Dense(1000,activation='relu'),
  keras.layers.Dense(10,activation='sigmoid')
])

model.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Train it for 50 epochs for better accuracy

# %%
model.fit(X_train,Y_train_categorical,epochs=5)
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 62s 40ms/step - loss: nan - accuracy: 0.1000
# Epoch 2/5
# 1563/1563 [==============================] - 59s 38ms/step - loss: nan - accuracy: 0.1000
# Epoch 3/5
# 1563/1563 [==============================] - 64s 41ms/step - loss: nan - accuracy: 0.1000
# Epoch 4/5
# 1563/1563 [==============================] - 54s 35ms/step - loss: nan - accuracy: 0.1000
# Epoch 5/5
# 1563/1563 [==============================] - 50s 32ms/step - loss: nan - accuracy: 0.1000
